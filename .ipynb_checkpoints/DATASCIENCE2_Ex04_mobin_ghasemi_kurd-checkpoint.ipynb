# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline
plt.rcParams["figure.figsize"] = (8, 6)

# %%
df = pd.read_csv('flights.csv')
df.head(10)
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
# 5   5  2013      1    1     554.0             558       -4.0     740.0
# 6   6  2013      1    1     555.0             600       -5.0     913.0
# 7   7  2013      1    1     557.0             600       -3.0     709.0
# 8   8  2013      1    1     557.0             600       -3.0     838.0
# 9   9  2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
# 5             728       12.0  ...   1696   N39463    EWR  ORD    150.0
# 6             854       19.0  ...    507   N516JB    EWR  FLL    158.0
# 7             723      -14.0  ...   5708   N829AS    LGA  IAD     53.0
# 8             846       -8.0  ...     79   N593JB    JFK  MCO    140.0
# 9             745        8.0  ...    301   N3ALAA    LGA  ORD    138.0
#
#    distance  hour  minute            time_hour                      name
# 0      1400     5      15  2013-01-01 05:00:00     United Air Lines Inc.
# 1      1416     5      29  2013-01-01 05:00:00     United Air Lines Inc.
# 2      1089     5      40  2013-01-01 05:00:00    American Airlines Inc.
# 3      1576     5      45  2013-01-01 05:00:00           JetBlue Airways
# 4       762     6       0  2013-01-01 06:00:00      Delta Air Lines Inc.
# 5       719     5      58  2013-01-01 05:00:00     United Air Lines Inc.
# 6      1065     6       0  2013-01-01 06:00:00           JetBlue Airways
# 7       229     6       0  2013-01-01 06:00:00  ExpressJet Airlines Inc.
# 8       944     6       0  2013-01-01 06:00:00           JetBlue Airways
# 9       733     6       0  2013-01-01 06:00:00    American Airlines Inc.
#
# [10 rows x 21 columns]

# %%
df.tail(10)
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 336766  336766  2013      9   30    2240.0            2250      -10.0
# 336767  336767  2013      9   30    2241.0            2246       -5.0
# 336768  336768  2013      9   30    2307.0            2255       12.0
# 336769  336769  2013      9   30    2349.0            2359      -10.0
# 336770  336770  2013      9   30       NaN            1842        NaN
# 336771  336771  2013      9   30       NaN            1455        NaN
# 336772  336772  2013      9   30       NaN            2200        NaN
# 336773  336773  2013      9   30       NaN            1210        NaN
# 336774  336774  2013      9   30       NaN            1159        NaN
# 336775  336775  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 336766    2347.0               7      -20.0  ...   2002   N281JB    JFK  BUF
# 336767    2345.0               1      -16.0  ...    486   N346JB    JFK  ROC
# 336768    2359.0            2358        1.0  ...    718   N565JB    JFK  BOS
# 336769     325.0             350      -25.0  ...    745   N516JB    JFK  PSE
# 336770       NaN            2019        NaN  ...   5274   N740EV    LGA  BNA
# 336771       NaN            1634        NaN  ...   3393      NaN    JFK  DCA
# 336772       NaN            2312        NaN  ...   3525      NaN    LGA  SYR
# 336773       NaN            1330        NaN  ...   3461   N535MQ    LGA  BNA
# 336774       NaN            1344        NaN  ...   3572   N511MQ    LGA  CLE
# 336775       NaN            1020        NaN  ...   3531   N839MQ    LGA  RDU
#
#        air_time  distance  hour  minute            time_hour  \
# 336766     52.0       301    22      50  2013-09-30 22:00:00
# 336767     47.0       264    22      46  2013-09-30 22:00:00
# 336768     33.0       187    22      55  2013-09-30 22:00:00
# 336769    196.0      1617    23      59  2013-09-30 23:00:00
# 336770      NaN       764    18      42  2013-09-30 18:00:00
# 336771      NaN       213    14      55  2013-09-30 14:00:00
# 336772      NaN       198    22       0  2013-09-30 22:00:00
# 336773      NaN       764    12      10  2013-09-30 12:00:00
# 336774      NaN       419    11      59  2013-09-30 11:00:00
# 336775      NaN       431     8      40  2013-09-30 08:00:00
#
#                             name
# 336766           JetBlue Airways
# 336767           JetBlue Airways
# 336768           JetBlue Airways
# 336769           JetBlue Airways
# 336770  ExpressJet Airlines Inc.
# 336771         Endeavor Air Inc.
# 336772         Endeavor Air Inc.
# 336773                 Envoy Air
# 336774                 Envoy Air
# 336775                 Envoy Air
#
# [10 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'name'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 21

# %%
pd.crosstab(df.columns, "")
# Out:
# col_0
# row_0
# air_time        1
# arr_delay       1
# arr_time        1
# carrier         1
# day             1
# dep_delay       1
# dep_time        1
# dest            1
# distance        1
# flight          1
# hour            1
# id              1
# minute          1
# month           1
# name            1
# origin          1
# sched_arr_time  1
# sched_dep_time  1
# tailnum         1
# time_hour       1
# year            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int64
#  2   month           336776 non-null  int64
#  3   day             336776 non-null  int64
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float64
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float64
#  10  carrier         336776 non-null  object
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  object
#  13  origin          336776 non-null  object
#  14  dest            336776 non-null  object
#  15  air_time        327346 non-null  float64
#  16  distance        336776 non-null  int64
#  17  hour            336776 non-null  int64
#  18  minute          336776 non-null  int64
#  19  time_hour       336776 non-null  object
#  20  name            336776 non-null  object
# dtypes: float64(5), int64(10), object(6)
# memory usage: 54.0+ MB

# %%
df.describe(include="all").T
# Out:
#                    count unique                    top    freq         mean  \
# id              336776.0    NaN                    NaN     NaN     168387.5
# year            336776.0    NaN                    NaN     NaN       2013.0
# month           336776.0    NaN                    NaN     NaN      6.54851
# day             336776.0    NaN                    NaN     NaN    15.710787
# dep_time        328521.0    NaN                    NaN     NaN  1349.109947
# sched_dep_time  336776.0    NaN                    NaN     NaN   1344.25484
# dep_delay       328521.0    NaN                    NaN     NaN     12.63907
# arr_time        328063.0    NaN                    NaN     NaN  1502.054999
# sched_arr_time  336776.0    NaN                    NaN     NaN   1536.38022
# arr_delay       327346.0    NaN                    NaN     NaN     6.895377
# carrier           336776     16                     UA   58665          NaN
# flight          336776.0    NaN                    NaN     NaN   1971.92362
# tailnum           334264   4043                 N725MQ     575          NaN
# origin            336776      3                    EWR  120835          NaN
# dest              336776    105                    ORD   17283          NaN
# air_time        327346.0    NaN                    NaN     NaN    150.68646
# distance        336776.0    NaN                    NaN     NaN  1039.912604
# hour            336776.0    NaN                    NaN     NaN    13.180247
# minute          336776.0    NaN                    NaN     NaN      26.2301
# time_hour         336776   6936    2013-09-13 08:00:00      94          NaN
# name              336776     16  United Air Lines Inc.   58665          NaN
#
#                          std     min       25%       50%        75%       max
# id              97219.001466     0.0  84193.75  168387.5  252581.25  336775.0
# year                     0.0  2013.0    2013.0    2013.0     2013.0    2013.0
# month               3.414457     1.0       4.0       7.0       10.0      12.0
# day                 8.768607     1.0       8.0      16.0       23.0      31.0
# dep_time          488.281791     1.0     907.0    1401.0     1744.0    2400.0
# sched_dep_time    467.335756   106.0     906.0    1359.0     1729.0    2359.0
# dep_delay          40.210061   -43.0      -5.0      -2.0       11.0    1301.0
# arr_time          533.264132     1.0    1104.0    1535.0     1940.0    2400.0
# sched_arr_time    497.457142     1.0    1124.0    1556.0     1945.0    2359.0
# arr_delay          44.633292   -86.0     -17.0      -5.0       14.0    1272.0
# carrier                  NaN     NaN       NaN       NaN        NaN       NaN
# flight           1632.471938     1.0     553.0    1496.0     3465.0    8500.0
# tailnum                  NaN     NaN       NaN       NaN        NaN       NaN
# origin                   NaN     NaN       NaN       NaN        NaN       NaN
# dest                     NaN     NaN       NaN       NaN        NaN       NaN
# air_time           93.688305    20.0      82.0     129.0      192.0     695.0
# distance          733.233033    17.0     502.0     872.0     1389.0    4983.0
# hour                4.661316     1.0       9.0      13.0       17.0      23.0
# minute             19.300846     0.0       8.0      29.0       44.0      59.0
# time_hour                NaN     NaN       NaN       NaN        NaN       NaN
# name                     NaN     NaN       NaN       NaN        NaN       NaN

# %%
df.describe(include = ["object"])
# Out:
#        carrier tailnum  origin    dest            time_hour  \
# count   336776  334264  336776  336776               336776
# unique      16    4043       3     105                 6936
# top         UA  N725MQ     EWR     ORD  2013-09-13 08:00:00
# freq     58665     575  120835   17283                   94
#
#                          name
# count                  336776
# unique                     16
# top     United Air Lines Inc.
# freq                    58665

# %%
df.dropna(inplace=True)

# %%
df.describe(include="all").T
# Out:
#                    count unique                    top    freq           mean  \
# id              327346.0    NaN                    NaN     NaN  168190.637793
# year            327346.0    NaN                    NaN     NaN         2013.0
# month           327346.0    NaN                    NaN     NaN       6.564803
# day             327346.0    NaN                    NaN     NaN      15.740825
# dep_time        327346.0    NaN                    NaN     NaN    1348.789883
# sched_dep_time  327346.0    NaN                    NaN     NaN    1340.335098
# dep_delay       327346.0    NaN                    NaN     NaN      12.555156
# arr_time        327346.0    NaN                    NaN     NaN    1501.908238
# sched_arr_time  327346.0    NaN                    NaN     NaN    1532.788426
# arr_delay       327346.0    NaN                    NaN     NaN       6.895377
# carrier           327346     16                     UA   57782            NaN
# flight          327346.0    NaN                    NaN     NaN    1943.104501
# tailnum           327346   4037                 N725MQ     544            NaN
# origin            327346      3                    EWR  117127            NaN
# dest              327346    104                    ATL   16837            NaN
# air_time        327346.0    NaN                    NaN     NaN      150.68646
# distance        327346.0    NaN                    NaN     NaN    1048.371314
# hour            327346.0    NaN                    NaN     NaN       13.14101
# minute          327346.0    NaN                    NaN     NaN      26.234116
# time_hour         327346   6922    2013-09-20 08:00:00      94            NaN
# name              327346     16  United Air Lines Inc.   57782            NaN
#
#                          std     min       25%       50%        75%       max
# id              97510.314383     0.0  83007.25  168251.5  252782.75  336769.0
# year                     0.0  2013.0    2013.0    2013.0     2013.0    2013.0
# month               3.413444     1.0       4.0       7.0       10.0      12.0
# day                 8.777376     1.0       8.0      16.0       23.0      31.0
# dep_time          488.319979     1.0     907.0    1400.0     1744.0    2400.0
# sched_dep_time    467.413156   500.0     905.0    1355.0     1729.0    2359.0
# dep_delay          40.065688   -43.0      -5.0      -2.0       11.0    1301.0
# arr_time          532.888731     1.0    1104.0    1535.0     1940.0    2400.0
# sched_arr_time    497.979124     1.0    1122.0    1554.0     1944.0    2359.0
# arr_delay          44.633292   -86.0     -17.0      -5.0       14.0    1272.0
# carrier                  NaN     NaN       NaN       NaN        NaN       NaN
# flight           1621.523684     1.0     544.0    1467.0     3412.0    8500.0
# tailnum                  NaN     NaN       NaN       NaN        NaN       NaN
# origin                   NaN     NaN       NaN       NaN        NaN       NaN
# dest                     NaN     NaN       NaN       NaN        NaN       NaN
# air_time           93.688305    20.0      82.0     129.0      192.0     695.0
# distance          735.908523    80.0     509.0     888.0     1389.0    4983.0
# hour                4.662063     5.0       9.0      13.0       17.0      23.0
# minute             19.295918     0.0       8.0      29.0       44.0      59.0
# time_hour                NaN     NaN       NaN       NaN        NaN       NaN
# name                     NaN     NaN       NaN       NaN        NaN       NaN

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe(include="all").T
# Out:
#                    count unique                    top    freq           mean  \
# id              327346.0    NaN                    NaN     NaN  168190.637793
# year            327346.0    NaN                    NaN     NaN         2013.0
# month           327346.0    NaN                    NaN     NaN       6.564803
# day             327346.0    NaN                    NaN     NaN      15.740825
# dep_time        327346.0    NaN                    NaN     NaN    1348.789883
# sched_dep_time  327346.0    NaN                    NaN     NaN    1340.335098
# dep_delay       327346.0    NaN                    NaN     NaN      12.555156
# arr_time        327346.0    NaN                    NaN     NaN    1501.908238
# sched_arr_time  327346.0    NaN                    NaN     NaN    1532.788426
# arr_delay       327346.0    NaN                    NaN     NaN       6.895377
# carrier           327346     16                     UA   57782            NaN
# flight          327346.0    NaN                    NaN     NaN    1943.104501
# tailnum           327346   4037                 N725MQ     544            NaN
# origin            327346      3                    EWR  117127            NaN
# dest              327346    104                    ATL   16837            NaN
# air_time        327346.0    NaN                    NaN     NaN      150.68646
# distance        327346.0    NaN                    NaN     NaN    1048.371314
# hour            327346.0    NaN                    NaN     NaN       13.14101
# minute          327346.0    NaN                    NaN     NaN      26.234116
# time_hour         327346   6922    2013-09-20 08:00:00      94            NaN
# name              327346     16  United Air Lines Inc.   57782            NaN
#
#                          std     min       25%       50%        75%       max
# id              97510.314383     0.0  83007.25  168251.5  252782.75  336769.0
# year                     0.0  2013.0    2013.0    2013.0     2013.0    2013.0
# month               3.413444     1.0       4.0       7.0       10.0      12.0
# day                 8.777376     1.0       8.0      16.0       23.0      31.0
# dep_time          488.319979     1.0     907.0    1400.0     1744.0    2400.0
# sched_dep_time    467.413156   500.0     905.0    1355.0     1729.0    2359.0
# dep_delay          40.065688   -43.0      -5.0      -2.0       11.0    1301.0
# arr_time          532.888731     1.0    1104.0    1535.0     1940.0    2400.0
# sched_arr_time    497.979124     1.0    1122.0    1554.0     1944.0    2359.0
# arr_delay          44.633292   -86.0     -17.0      -5.0       14.0    1272.0
# carrier                  NaN     NaN       NaN       NaN        NaN       NaN
# flight           1621.523684     1.0     544.0    1467.0     3412.0    8500.0
# tailnum                  NaN     NaN       NaN       NaN        NaN       NaN
# origin                   NaN     NaN       NaN       NaN        NaN       NaN
# dest                     NaN     NaN       NaN       NaN        NaN       NaN
# air_time           93.688305    20.0      82.0     129.0      192.0     695.0
# distance          735.908523    80.0     509.0     888.0     1389.0    4983.0
# hour                4.662063     5.0       9.0      13.0       17.0      23.0
# minute             19.295918     0.0       8.0      29.0       44.0      59.0
# time_hour                NaN     NaN       NaN       NaN        NaN       NaN
# name                     NaN     NaN       NaN       NaN        NaN       NaN

# %%
df.columns
# Out:
# Index(['id', 'year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'name'],
#       dtype='object')

# %%
print(len(df[['dep_time', 'sched_dep_time']].apply(lambda x: x[x < 1000]).dropna()) / len(df) * 100, "%")
# Out:
# 28.748174714216763 %

# %%
print(len(df[['distance']].apply(lambda x: x[x > 2000]).dropna()) / len(df) * 100, "%")
# Out:
# 15.635443842295308 %

# %%
df["carrier"].value_counts()
# Out:
# UA    57782
# B6    54049
# EV    51108
# DL    47658
# AA    31947
# MQ    25037
# US    19831
# 9E    17294
# WN    12044
# VX     5116
# FL     3175
# AS      709
# F9      681
# YV      544
# HA      342
# OO       29
# Name: carrier, dtype: int64

# %%
df["tailnum"].value_counts()
# Out:
# N725MQ    544
# N722MQ    485
# N723MQ    475
# N711MQ    462
# N713MQ    449
#          ...
# N456UW      1
# N26906      1
# N809NW      1
# N941UW      1
# N557AS      1
# Name: tailnum, Length: 4037, dtype: int64

# %%
df["origin"].value_counts()
# Out:
# EWR    117127
# JFK    109079
# LGA    101140
# Name: origin, dtype: int64

# %%
df["dest"].value_counts()
# Out:
# ATL    16837
# ORD    16566
# LAX    16026
# BOS    15022
# MCO    13967
#        ...
# HDN       14
# MTJ       14
# SBN       10
# ANC        8
# LEX        1
# Name: dest, Length: 104, dtype: int64

# %%
df["time_hour"].value_counts()
# Out:
# 2013-09-20 08:00:00    94
# 2013-09-23 08:00:00    93
# 2013-09-16 08:00:00    92
# 2013-09-09 08:00:00    92
# 2013-09-19 08:00:00    92
#                        ..
# 2013-10-21 23:00:00     1
# 2013-10-22 23:00:00     1
# 2013-09-22 23:00:00     1
# 2013-10-24 23:00:00     1
# 2013-09-30 23:00:00     1
# Name: time_hour, Length: 6922, dtype: int64

# %%
df["name"].value_counts()
# Out:
# United Air Lines Inc.          57782
# JetBlue Airways                54049
# ExpressJet Airlines Inc.       51108
# Delta Air Lines Inc.           47658
# American Airlines Inc.         31947
# Envoy Air                      25037
# US Airways Inc.                19831
# Endeavor Air Inc.              17294
# Southwest Airlines Co.         12044
# Virgin America                  5116
# AirTran Airways Corporation     3175
# Alaska Airlines Inc.             709
# Frontier Airlines Inc.           681
# Mesa Airlines Inc.               544
# Hawaiian Airlines Inc.           342
# SkyWest Airlines Inc.             29
# Name: name, dtype: int64

# %%
df["origin"].value_counts(normalize = True) * 100
# Out:
# EWR    35.780795
# JFK    33.322234
# LGA    30.896971
# Name: origin, dtype: float64

# %%
df["dest"].value_counts(normalize = True) * 100
# Out:
# ATL    5.143487
# ORD    5.060700
# LAX    4.895737
# BOS    4.589028
# MCO    4.266739
#          ...
# HDN    0.004277
# MTJ    0.004277
# SBN    0.003055
# ANC    0.002444
# LEX    0.000305
# Name: dest, Length: 104, dtype: float64

# %%
df.sort_values(by = "arr_delay", ascending = False).head()
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 7072      7072  2013      1    9     641.0             900     1301.0
# 235778  235778  2013      6   15    1432.0            1935     1137.0
# 8239      8239  2013      1   10    1121.0            1635     1126.0
# 327043  327043  2013      9   20    1139.0            1845     1014.0
# 270376  270376  2013      7   22     845.0            1600     1005.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 7072      1242.0            1530     1272.0  ...     51   N384HA    JFK  HNL
# 235778    1607.0            2120     1127.0  ...   3535   N504MQ    JFK  CMH
# 8239      1239.0            1810     1109.0  ...   3695   N517MQ    EWR  ORD
# 327043    1457.0            2210     1007.0  ...    177   N338AA    JFK  SFO
# 270376    1044.0            1815      989.0  ...   3075   N665MQ    JFK  CVG
#
#        air_time  distance  hour  minute            time_hour  \
# 7072      640.0      4983     9       0  2013-01-09 09:00:00
# 235778     74.0       483    19      35  2013-06-15 19:00:00
# 8239      111.0       719    16      35  2013-01-10 16:00:00
# 327043    354.0      2586    18      45  2013-09-20 18:00:00
# 270376     96.0       589    16       0  2013-07-22 16:00:00
#
#                           name
# 7072    Hawaiian Airlines Inc.
# 235778               Envoy Air
# 8239                 Envoy Air
# 327043  American Airlines Inc.
# 270376               Envoy Air
#
# [5 rows x 21 columns]

# %%
df.sort_values(by = ["year", "arr_time", "distance"], ascending = [False, False, True]).head()
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 11249    11249  2013      1   13    2243.0            2129       74.0
# 215851  215851  2013      5   24    2310.0            2159       71.0
# 246641  246641  2013      6   26    2208.0            2000      128.0
# 250340  250340  2013      6   30    2259.0            2100      119.0
# 24217    24217  2013      1   28    2303.0            2250       13.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# 11249     2400.0            2224       96.0  ...   4619   N16963    EWR  PHL
# 215851    2400.0            2304       56.0  ...   4276   N11165    EWR  BDL
# 246641    2400.0            2127      153.0  ...   4287   N8946A    JFK  BWI
# 250340    2400.0            2210      110.0  ...   2144   N963UW    LGA  BOS
# 24217     2400.0            2354        6.0  ...   1018   N706JB    JFK  BOS
#
#        air_time  distance  hour  minute            time_hour  \
# 11249      31.0        80    21      29  2013-01-13 21:00:00
# 215851     24.0       116    21      59  2013-05-24 21:00:00
# 246641     35.0       184    20       0  2013-06-26 20:00:00
# 250340     46.0       184    21       0  2013-06-30 21:00:00
# 24217      34.0       187    22      50  2013-01-28 22:00:00
#
#                             name
# 11249   ExpressJet Airlines Inc.
# 215851  ExpressJet Airlines Inc.
# 246641         Endeavor Air Inc.
# 250340           US Airways Inc.
# 24217            JetBlue Airways
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'name'],
#       dtype='object')

# %%
x = df["dep_time"].mean()
df["dep_time"].fillna(x, inplace=True)

# %%
x = df["sched_dep_time"].mean()
df["sched_dep_time"].fillna(x, inplace=True)

# %%
x = df["dep_delay"].mean()
df["dep_delay"].fillna(x, inplace=True)

# %%
x = df["arr_time"].mean()
df["arr_time"].fillna(x, inplace=True)

# %%
x = df["sched_arr_time"].mean()
df["sched_arr_time"].fillna(x, inplace=True)

# %%
x = df["arr_delay"].mean()
df["arr_delay"].fillna(x, inplace=True)

# %%
x = df["air_time"].mean()
df["air_time"].fillna(x, inplace=True)

# %%
x = df["distance"].mean()
df["distance"].fillna(x, inplace=True)

# %%
x = df["hour"].mean()
df["hour"].fillna(x, inplace=True)

# %%
x = df["minute"].mean()
df["minute"].fillna(x, inplace=True)

# %%
for x in df.index:
    if df.loc[x, "hour"] >= 24:
        df.drop(x, inplace=True)

# %%
for x in df.index:
    if df.loc[x, "minute"] >= 60:
        df.drop(x, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.corr()
# Out:
# C:\Users\mobinghk\AppData\Local\Temp\ipykernel_7272\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       id  year     month       day  dep_time  sched_dep_time  \
# id              1.000000   NaN  0.069908  0.087998  0.001921        0.000332
# year                 NaN   NaN       NaN       NaN       NaN             NaN
# month           0.069908   NaN  1.000000  0.005036 -0.003735       -0.003358
# day             0.087998   NaN  0.005036  1.000000 -0.000393        0.000077
# dep_time        0.001921   NaN -0.003735 -0.000393  1.000000        0.954827
# sched_dep_time  0.000332   NaN -0.003358  0.000077  0.954827        1.000000
# dep_delay       0.049187   NaN -0.020055  0.000591  0.259613        0.198924
# arr_time       -0.024916   NaN -0.002457 -0.005404  0.662509        0.644387
# sched_arr_time -0.016895   NaN -0.003145 -0.002286  0.784442        0.780587
# arr_delay       0.018613   NaN -0.017382 -0.000319  0.232306        0.173896
# flight         -0.000234   NaN  0.000980 -0.000849  0.041530        0.028401
# air_time       -0.032866   NaN  0.010924  0.002236 -0.014619       -0.015532
# distance        0.014855   NaN  0.020399  0.003216 -0.014134       -0.012933
# hour           -0.000591   NaN -0.003986  0.000041  0.953515        0.999149
# minute          0.022327   NaN  0.014984  0.000874  0.091416        0.083106
#
#                 dep_delay  arr_time  sched_arr_time  arr_delay    flight  \
# id               0.049187 -0.024916       -0.016895   0.018613 -0.000234
# year                  NaN       NaN             NaN        NaN       NaN
# month           -0.020055 -0.002457       -0.003145  -0.017382  0.000980
# day              0.000591 -0.005404       -0.002286  -0.000319 -0.000849
# dep_time         0.259613  0.662509        0.784442   0.232306  0.041530
# sched_dep_time   0.198924  0.644387        0.780587   0.173896  0.028401
# dep_delay        1.000000  0.029421        0.160497   0.914803  0.053970
# arr_time         0.029421  1.000000        0.790789   0.024482  0.025007
# sched_arr_time   0.160497  0.790789        1.000000   0.133261  0.013947
# arr_delay        0.914803  0.024482        0.133261   1.000000  0.072862
# flight           0.053970  0.025007        0.013947   0.072862  1.000000
# air_time        -0.022405  0.054296        0.078918  -0.035297 -0.472838
# distance        -0.021681  0.047189        0.073614  -0.061868 -0.481460
# hour             0.198269  0.644368        0.780562   0.173456  0.027781
# minute           0.028251  0.040746        0.049435   0.021522  0.016756
#
#                 air_time  distance      hour    minute
# id             -0.032866  0.014855 -0.000591  0.022327
# year                 NaN       NaN       NaN       NaN
# month           0.010924  0.020399 -0.003986  0.014984
# day             0.002236  0.003216  0.000041  0.000874
# dep_time       -0.014619 -0.014134  0.953515  0.091416
# sched_dep_time -0.015532 -0.012933  0.999149  0.083106
# dep_delay      -0.022405 -0.021681  0.198269  0.028251
# arr_time        0.054296  0.047189  0.644368  0.040746
# sched_arr_time  0.078918  0.073614  0.780562  0.049435
# arr_delay      -0.035297 -0.061868  0.173456  0.021522
# flight         -0.472838 -0.481460  0.027781  0.016756
# air_time        1.000000  0.990650 -0.016277  0.017032
# distance        0.990650  1.000000 -0.013731  0.018472
# hour           -0.016277 -0.013731  1.000000  0.041931
# minute          0.017032  0.018472  0.041931  1.000000

# %%
df.isnull().sum()
# Out:
# id                0
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         0
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          0
# distance          0
# hour              0
# minute            0
# time_hour         0
# name              0
# dtype: int64

# %%
pd.crosstab(df["origin"], df["dest"], normalize = 'index')
# Out:
# dest         ABQ      ACK       ALB       ANC       ATL       AUS       AVL  \
# origin
# EWR     0.000000  0.00000  0.003569  0.000068  0.041630  0.008171  0.002143
# JFK     0.002329  0.00242  0.000000  0.000000  0.017602  0.013330  0.000000
# LGA     0.000000  0.00000  0.000000  0.000000  0.099278  0.000000  0.000099
#
# dest         BDL      BGR       BHM  ...       SNA       SRQ       STL  \
# origin                               ...
# EWR     0.003518  0.00000  0.000000  ...  0.006933  0.000000  0.020269
# JFK     0.000000  0.00000  0.000009  ...  0.000000  0.004327  0.000009
# LGA     0.000000  0.00354  0.002650  ...  0.000000  0.007208  0.017471
#
# dest         STT       SYR       TPA      TUL       TVC       TYS       XNA
# origin
# EWR     0.001605  0.001247  0.019765  0.00251  0.000188  0.002672  0.002416
# JFK     0.003025  0.011845  0.027035  0.00000  0.000000  0.000000  0.000000
# LGA     0.000000  0.002660  0.021020  0.00000  0.000722  0.002620  0.007010
#
# [3 rows x 104 columns]

# %%
pd.crosstab(df["name"], df["carrier"])
# Out:
# carrier                         9E     AA   AS     B6     DL     EV   F9  \
# name
# AirTran Airways Corporation      0      0    0      0      0      0    0
# Alaska Airlines Inc.             0      0  709      0      0      0    0
# American Airlines Inc.           0  31947    0      0      0      0    0
# Delta Air Lines Inc.             0      0    0      0  47658      0    0
# Endeavor Air Inc.            17294      0    0      0      0      0    0
# Envoy Air                        0      0    0      0      0      0    0
# ExpressJet Airlines Inc.         0      0    0      0      0  51108    0
# Frontier Airlines Inc.           0      0    0      0      0      0  681
# Hawaiian Airlines Inc.           0      0    0      0      0      0    0
# JetBlue Airways                  0      0    0  54049      0      0    0
# Mesa Airlines Inc.               0      0    0      0      0      0    0
# SkyWest Airlines Inc.            0      0    0      0      0      0    0
# Southwest Airlines Co.           0      0    0      0      0      0    0
# US Airways Inc.                  0      0    0      0      0      0    0
# United Air Lines Inc.            0      0    0      0      0      0    0
# Virgin America                   0      0    0      0      0      0    0
#
# carrier                        FL   HA     MQ  OO     UA     US    VX     WN  \
# name
# AirTran Airways Corporation  3175    0      0   0      0      0     0      0
# Alaska Airlines Inc.            0    0      0   0      0      0     0      0
# American Airlines Inc.          0    0      0   0      0      0     0      0
# Delta Air Lines Inc.            0    0      0   0      0      0     0      0
# Endeavor Air Inc.               0    0      0   0      0      0     0      0
# Envoy Air                       0    0  25037   0      0      0     0      0
# ExpressJet Airlines Inc.        0    0      0   0      0      0     0      0
# Frontier Airlines Inc.          0    0      0   0      0      0     0      0
# Hawaiian Airlines Inc.          0  342      0   0      0      0     0      0
# JetBlue Airways                 0    0      0   0      0      0     0      0
# Mesa Airlines Inc.              0    0      0   0      0      0     0      0
# SkyWest Airlines Inc.           0    0      0  29      0      0     0      0
# Southwest Airlines Co.          0    0      0   0      0      0     0  12044
# US Airways Inc.                 0    0      0   0      0  19831     0      0
# United Air Lines Inc.           0    0      0   0  57782      0     0      0
# Virgin America                  0    0      0   0      0      0  5116      0
#
# carrier                       YV
# name
# AirTran Airways Corporation    0
# Alaska Airlines Inc.           0
# American Airlines Inc.         0
# Delta Air Lines Inc.           0
# Endeavor Air Inc.              0
# Envoy Air                      0
# ExpressJet Airlines Inc.       0
# Frontier Airlines Inc.         0
# Hawaiian Airlines Inc.         0
# JetBlue Airways                0
# Mesa Airlines Inc.           544
# SkyWest Airlines Inc.          0
# Southwest Airlines Co.         0
# US Airways Inc.                0
# United Air Lines Inc.          0
# Virgin America                 0

# %%
df.pivot_table(
    ["dep_time", "sched_dep_time", "dep_delay", "arr_time"],
    ["carrier"],
    aggfunc = ["mean", "count"],
).head(10)
# Out:
#                 mean                                           count  \
#             arr_time  dep_delay     dep_time sched_dep_time arr_time
# carrier
# 9E       1638.418411  16.439574  1485.516017    1462.459119    17294
# AA       1521.329515   8.569130  1297.093561    1287.690550    31947
# AS       1566.758815   5.830748  1296.973202    1286.911142      709
# B6       1405.744399  12.967548  1380.708357    1396.206831    54049
# DL       1572.671346   9.223950  1350.931344    1346.273259    47658
# EV       1488.194881  19.838929  1368.105032    1343.567035    51108
# F9       1672.480176  20.201175  1437.954479    1407.826725      681
# FL       1574.061417  18.605984  1386.441575    1372.068661     3175
# HA       1474.225146   4.900585   948.760234     974.385965      342
# MQ       1550.661940  10.445381  1392.182610    1379.161840    25037
#
#
#         dep_delay dep_time sched_dep_time
# carrier
# 9E          17294    17294          17294
# AA          31947    31947          31947
# AS            709      709            709
# B6          54049    54049          54049
# DL          47658    47658          47658
# EV          51108    51108          51108
# F9            681      681            681
# FL           3175     3175           3175
# HA            342      342            342
# MQ          25037    25037          25037

# %%
df.columns
# Out:
# Index(['id', 'year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'name'],
#       dtype='object')

# %%
df['arr_delay'].kurtosis()
# Out:
# 29.233043998766767

# %%
df['arr_delay'].skew()
# Out:
# 3.716817480457187

# %%
df['arr_delay'].std()
# Out:
# 44.63329169019526

# %%
df['arr_delay'].mean()
# Out:
# 6.89537675731489

# %%
df['arr_delay'].mode()
# Out:
# 0   -13.0
# Name: arr_delay, dtype: float64

# %%
df['arr_delay'].median()
# Out:
# -5.0

# %%
df['arr_delay'][df['arr_delay'] < 200].hist(bins=300)
# Out:
# <Axes: >

# %%
pd.plotting.scatter_matrix(
    df[["dep_delay", "arr_delay", "distance"]],
    figsize = (15, 15),
    diagonal = "kde")
plt.show()

# %%
df["carrier"].hist()
# Out:
# <Axes: >

# %%
df["origin"].hist()
# Out:
# <Axes: >

# %%
df["flight"].hist()
# Out:
# <Axes: >

# %%
df.hist(color = "k",
        bins = 20,
        figsize = (15, 10))
plt.show()

# %%
df.boxplot(column = "dep_time",
           by = "origin")
plt.show()

# %%
df.boxplot(column = "arr_time",
           by = "origin")
plt.show()

# %%
df.boxplot(column = "distance",
           by = "origin")
plt.show()

# %%
df.boxplot(column = "air_time",
           by = "origin")
plt.show()

# %%
sns.heatmap(df["arr_delay"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 sns.heatmap(df["arr_delay"])
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:115, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     112 # Validate the mask and convert to DataFrame
#     113 mask = _matrix_mask(data, mask)
# --> 115 plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#     117 # Get good names for the rows and columns
#     118 xtickevery = 1
#
# File ~\anaconda3\lib\site-packages\numpy\ma\core.py:1926, in masked_where(condition, a, copy)
#    1924 (cshape, ashape) = (cond.shape, a.shape)
#    1925 if cshape and cshape != ashape:
# -> 1926     raise IndexError("Inconsistent shape between the condition and the input"
#    1927                      " (got %s and %s)" % (cshape, ashape))
#    1928 if hasattr(a, '_mask'):
#    1929     cond = mask_or(cond, a._mask)
#
# IndexError: Inconsistent shape between the condition and the input (got (327346, 1) and (327346,))
